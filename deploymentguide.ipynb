# %% [markdown]
# # **Model Deployment**
#
# ### ✅ Deployed Web Application
# The trained machine learning model for sensor fault detection has been deployed successfully as a web-based application.
#
# **Access the deployed application here:**
# 🔗 [https://pumpfaultprediction.streamlit.app/](https://pumpfaultprediction.streamlit.app/)
#
# ---
#
# ### 📘 Deployment Overview
#
# The application is built using **Streamlit**, a Python framework ideal for deploying interactive machine learning tools. It allows users to upload sensor data and receive fault predictions in real time. The backend model includes a data preprocessing pipeline with scaling and PCA transformation, followed by a trained classifier.
#
# ---
#
# ### 🧭 How to Use the Application
#
# 1. **Prepare Your Data**
#    - Create a `.csv` file containing **50 columns** labeled `sensor_00`, `sensor_01`, ..., up to `sensor_49`.
#    - Each row should represent one observation or reading from the sensors.
#
# 2. **Visit the Application**
#    Open the app in any modern web browser:
#    [https://pumpfaultprediction.streamlit.app/](https://pumpfaultprediction.streamlit.app/)
#
# 3. **Upload the CSV File**
#    - Use the sidebar panel to upload your CSV file.
#    - Ensure that your file has exactly 50 columns; otherwise, it will return an error message.
#
# 4. **Run the Prediction**
#    - After uploading, click the **"🛰️ Predict Faults"** button.
#    - The app will preprocess the data (scaling and dimensionality reduction) and generate predictions using the trained model.
#
# 5. **View and Download Results**
#    - A preview of the prediction results will be shown on-screen.
#    - You can then download the full results as a CSV file containing the original data along with a new `Fault Prediction` column.
#
# ---
#
# ### 📌 Key Features
#
# - 📄 **CSV Upload:** User-friendly file uploader for sensor datasets.
# - ⚙️ **Preprocessing Pipeline:** Integrated data scaling and PCA for dimensionality reduction.
# - 🤖 **ML Prediction:** Applies a trained classifier to detect sensor faults.
# - 📥 **Results Export:** Allows downloading the prediction results for further analysis.
# - 🧾 **Interactive UI:** Responsive layout with clear instructions and feedback.
#
# ---
#
# ### 🛠️ Technical Details
#
# - **Framework:** Streamlit
# - **Model Artifacts:** Scaler, PCA transformer, and classification model serialized using `pickle`
# - **Hosting:** Streamlit Cloud
# - **Input Format:** CSV with 50 sensor columns
# - **Output Format:** CSV with original data + fault prediction column
#
# ---
